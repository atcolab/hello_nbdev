# %%
# default_exp core

# %% [markdown]
# # module name here
#
# > API details.

# %%
#hide
from nbdev.showdoc import *

# %%
#export
def say_hello(to):
    "Say hello to somebody"
    return f'Hello {to}!'

# %% [markdown]
# We can use this to say hello to anyone at all!

# %%
say_hello('atcolab')
# Out:
# 'Hello atcolab!'

# %%
assert say_hello("atcolab")=="Hello atcolab!"
